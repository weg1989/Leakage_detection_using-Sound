# %%
from IPython import display as ipd
import matplotlib.pyplot as plt
import numpy as np
import librosa
import librosa.display

# %%
audio_file = "Voice_8.wav"

# %%
ipd.Audio(audio_file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
signal , sr = librosa.load(audio_file)

# %%
signal.shape
# Out:
# (312816,)

# %%
# extract mfcc
mfccs = librosa.feature.mfcc(signal, n_mfcc=13, sr=sr)
# Out:
# C:\Users\Jay\AppData\Local\Temp\ipykernel_7448\1183743487.py:2: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.06858359 -0.01538549
#   0.04559097] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfccs = librosa.feature.mfcc(signal, n_mfcc=13, sr=sr)

# %%
mfccs.shape
# Out:
# (13, 611)

# %%
mfccs
# Out:
# array([[-764.0104   , -764.0104   , -547.3879   , ..., -106.46509  ,
#         -110.54683  , -121.234856 ],
#        [   0.       ,    0.       ,  -29.146807 , ...,   -6.867585 ,
#          -10.00713  ,   -9.00906  ],
#        [   0.       ,    0.       ,  -43.564438 , ...,  -23.016722 ,
#          -20.971733 ,  -20.657887 ],
#        ...,
#        [   0.       ,    0.       ,  -13.994383 , ...,    5.1768   ,
#            7.142624 ,    9.649926 ],
#        [   0.       ,    0.       ,  -15.89015  , ...,   -3.4329314,
#           -1.5150152,   -2.1148245],
#        [   0.       ,    0.       ,   -6.417594 , ...,    5.255357 ,
#            4.7608094,    4.563202 ]], dtype=float32)

# %%
import pandas as pd
from sklearn.feature_selection import f_regression
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
X = pd.DataFrame(mfccs)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled
# Out:
# array([[-3.4641016 , -3.4641016 , -3.4511309 , ..., -3.3070004 ,
#         -3.3192687 , -3.3474686 ],
#        [ 0.28867513,  0.28867513,  0.17427   , ..., -0.0449386 ,
#         -0.13486391, -0.04885923],
#        [ 0.28867513,  0.28867513,  0.07341021, ..., -0.5738623 ,
#         -0.48214698, -0.39124867],
#        ...,
#        [ 0.28867513,  0.28867513,  0.28027013, ...,  0.34954447,
#          0.40832213,  0.49957713],
#        [ 0.28867513,  0.28867513,  0.26700813, ...,  0.0675547 ,
#          0.13410775,  0.15378037],
#        [ 0.28867513,  0.28867513,  0.33327422, ...,  0.3521174 ,
#          0.33288264,  0.350065  ]], dtype=float32)

# %%
pca = PCA(0.95)
X_pca = pca.fit_transform(X_scaled)
X_pca.shape
# Out:
# (13, 1)

# %%
MFCCS = X_pca.transpose()

# %%
X = pd.DataFrame(MFCCS)

# %%
X.to_csv('result.csv')
